# %%
# Schritt 1: Bibliotheken importieren
import numpy as np
import pandas as pd
import plotly.graph_objects as go
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential, Model,  load_model
from tensorflow.keras.layers import LSTM, Dense, Dropout, SimpleRNN
from keras.saving import save_model
import time
import os

# Parameter
#symbol = 'TSLA'


# ====== SETTINGS ======
# 1. Daten abrufen
folderPath_His = "/Users/Shared/ai_work/Trainingdata/ml_data/yh_his/D1/"
folderPath_models = "/Users/Shared/ai_work/Trainingdata/models/lstm_ta/"
folderpath_results = "/Users/Shared/ai_work/Trainingdata/ml_results/lstm_ta/"
# Schritt 5: Daten skalieren und Sequenzen vorbereiten
features = ['open', 'high', 'low', 'close', 'volume', 'SMA_20', 'EMA_20', 'RSI', 'MACD', 'Bollinger_Upper', 'Bollinger_lower']
# ===== END SETTINGS ======

lastBars = 10
n_tail = 200
#n_pred_days = 60
#n_time_steps = 60 # Neuronal Netzwerk
#sequence_length = 60
n_epochs = 100
n_batch_size = 16
pred_days = 60
look_back = 60
#data = df[['close']].dropna()

# %%
def displayChart (symbol, future_dates,pred_prices,  data, df_his):
    # Schritt 9: Ergebnisse plotten
    fig = go.Figure()
    df_his = df_his.set_index('date')
    df_his = df_his.tail (lastBars)
    fig.add_trace(go.Scatter(x=data.index[-200:], y=data['close'][-200:], name='Historische Kurse'))
    fig.add_trace(go.Scatter(x=df_his.index, y=df_his['close'],  name='IS HIS'  ))
    fig.add_trace(go.Scatter(x=future_dates, y=pred_prices, name='Prognose (100 Tage)'))
    fig.update_layout(title=  symbol+ '  Prognose mit LSTM und technischen Indikatoren', xaxis_title='Datum', yaxis_title='Preis (USD)')
    fig.show()

# %%
def build_model(X, y, model_name):
    # Schritt 6: LSTM-Modell erstellen
    model = Sequential([
    LSTM(100, return_sequences=True, input_shape=(X.shape[1], X.shape[2])),
    Dropout(0.2),
    LSTM(100),
    Dropout(0.2),
    Dense(pred_days)
    ])
    model.compile(optimizer='adam', loss='mse')
    # Schritt 7: Modell trainieren
    model.fit(X, y, epochs=n_epochs, batch_size=n_batch_size, verbose=1)
    
    save_model(model, model_name)
    return model

# %%
def predictBySymbol (symbol):
    
    df = pd.read_csv (folderPath_His + symbol + ".csv")
    df_his = df.tail(lastBars)
    df_his["date"] = pd.to_datetime(df_his["date"]) 
    df = df[['date','open', 'high', 'low', 'close','volume']]
    df['date'] = pd.to_datetime(df['date'])
    df = df.set_index('date')
    data = df.copy()
    #data = df.copy()
    if n_tail > 0: data = data.tail(n_tail)
    if lastBars > 0: data = data[: len(data)-lastBars]
    # Schritt 4: Technische Indikatoren berechnen
    data['SMA_20'] = data['close'].rolling(window=20).mean()
    data['EMA_20'] = data['close'].ewm(span=20, adjust=False).mean()
    change = data['close'].diff()
    gain = change.where(change > 0, 0).rolling(window=14).mean()
    loss = (-change.where(change < 0, 0)).rolling(window=14).mean()
    rs = gain / loss
    data['RSI'] = 100 - (100 / (1 + rs))

    ema12 = data['close'].ewm(span=12, adjust=False).mean()
    ema26 = data['close'].ewm(span=26, adjust=False).mean()
    data['MACD'] = ema12 - ema26

    std = data['close'].rolling(window=20).std()
    data['Bollinger_Upper'] = data['SMA_20'] + (std * 2)
    data['Bollinger_lower'] = data['SMA_20'] - (std * 2)

    data.fillna(method='bfill', inplace=True)
    scaler = MinMaxScaler()
    scaled_data = scaler.fit_transform(data[features])

    X, y = [], []
    for i in range(look_back, len(scaled_data) - pred_days):
       X.append(scaled_data[i - look_back:i])
       y.append(scaled_data[i:i + pred_days, 3])  # close-Preis
    X, y = np.array(X), np.array(y)

    filePath_model =  folderPath_models +symbol+ ".keras"
    model_name = filePath_model
    model_pred =""
    if os.path.exists(model_name):
       model_pred = build_model(X, y, model_name)
       model_pred = load_model(model_name)
    else:
       model_pred = build_model(X, y, model_name)
    # Schritt 8: Vorhersage für die nächsten 100 Handelstage
    last_seq = scaled_data[-look_back:]
    last_seq = np.expand_dims(last_seq, axis=0)

    pred_scaled = model_pred.predict(last_seq)[0]

    scaler_close = MinMaxScaler()
    scaler_close.fit(data[['close']])
    pred_prices = scaler_close.inverse_transform(pred_scaled.reshape(-1, 1)).flatten()

    future_dates = pd.date_range(start=data.index[-1], periods=pred_days+1, freq='B')[1:]
    
    #display Chart 
    

    displayChart (symbol, future_dates, pred_prices, data, df_his)

# %%
predictBySymbol ('#INTC')
# Out:
# Epoch 1/100
# /tmp/ipykernel_6455/1996713675.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_6455/1996713675.py:30: FutureWarning:
#
# DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#
# /home/aiubuntu01/anaconda3/envs/tf-gpu/lib/python3.12/site-packages/keras/src/layers/rnn/rnn.py:199: UserWarning:
#
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.2969
# Epoch 2/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.1426
# Epoch 3/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0872
# Epoch 4/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0698
# Epoch 5/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0550
# Epoch 6/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0490
# Epoch 7/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0386
# Epoch 8/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0369
# Epoch 9/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0306
# Epoch 10/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0255
# Epoch 11/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0237
# Epoch 12/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0229
# Epoch 13/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0218
# Epoch 14/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0218
# Epoch 15/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0203
# Epoch 16/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0210
# Epoch 17/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0191
# Epoch 18/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0189
# Epoch 19/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0178
# Epoch 20/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0179
# Epoch 21/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0171
# Epoch 22/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0165
# Epoch 23/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0173
# Epoch 24/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0164
# Epoch 25/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0161
# Epoch 26/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0147
# Epoch 27/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0162
# Epoch 28/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0178
# Epoch 29/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0166
# Epoch 30/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0145
# Epoch 31/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0146
# Epoch 32/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0142
# Epoch 33/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0142
# Epoch 34/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0140
# Epoch 35/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0150
# Epoch 36/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0127
# Epoch 37/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0128
# Epoch 38/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0125
# Epoch 39/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0121
# Epoch 40/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0118
# Epoch 41/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0108
# Epoch 42/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0122
# Epoch 43/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0106
# Epoch 44/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0104
# Epoch 45/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0109
# Epoch 46/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0108
# Epoch 47/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0101
# Epoch 48/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0103
# Epoch 49/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0106
# Epoch 50/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0106
# Epoch 51/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0106
# Epoch 52/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0110
# Epoch 53/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0107
# Epoch 54/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0100
# Epoch 55/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0102
# Epoch 56/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0097
# Epoch 57/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0094
# Epoch 58/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0098
# Epoch 59/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0089
# Epoch 60/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0100
# Epoch 61/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0089
# Epoch 62/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0090
# Epoch 63/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0090
# Epoch 64/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0097
# Epoch 65/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0087
# Epoch 66/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0084
# Epoch 67/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0102
# Epoch 68/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0085
# Epoch 69/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0089
# Epoch 70/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0088
# Epoch 71/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0080
# Epoch 72/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0083
# Epoch 73/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0086
# Epoch 74/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0090
# Epoch 75/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0081
# Epoch 76/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0089
# Epoch 77/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0100
# Epoch 78/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0085
# Epoch 79/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0089
# Epoch 80/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0081
# Epoch 81/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0088
# Epoch 82/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0081
# Epoch 83/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0082
# Epoch 84/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0083
# Epoch 85/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0085
# Epoch 86/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0081
# Epoch 87/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0082
# Epoch 88/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0085
# Epoch 89/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0079
# Epoch 90/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0077
# Epoch 91/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0077
# Epoch 92/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0073
# Epoch 93/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0077
# Epoch 94/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0068
# Epoch 95/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0077
# Epoch 96/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0077
# Epoch 97/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0071
# Epoch 98/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0073
# Epoch 99/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0069
# Epoch 100/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0071
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
