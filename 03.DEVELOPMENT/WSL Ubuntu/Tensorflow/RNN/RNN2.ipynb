# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential, Model,  load_model
from tensorflow.keras.layers import SimpleRNN, Dense


#from tensorflow.keras.models import Model
#from tensorflow.keras.layers import Input, LSTM, Dense, Bidirectional
from tensorflow.keras.callbacks import EarlyStopping
import time
from tensorflow.keras import mixed_precision
from keras.saving import save_model

#from tensorflow.keras.models import Model
#from tensorflow.keras.layers import Input, LSTM, Dense, Bidirectional
#from tensorflow.keras.callbacks import EarlyStopping
import time
#from tensorflow.keras import mixed_precision

import matplotlib.pyplot as plt
import datetime

# 1. Daten abrufen

end_date = datetime.datetime.now()
start_date = end_date - datetime.timedelta(days=365*2)  # 2 Jahre Historie

#df = yf.download(symbol, start=start_date, end=end_date)
#df = df[['close']].dropna()

# 1. Daten abrufen
folderPath_His = "/Users/Shared/ai_work/Trainingdata/ml_data/yh_his/D1/"
folderPath_models = "/Users/Shared/ai_work/Trainingdata/models/rnn/"
folderpath_results = "/Users/Shared/ai_work/Trainingdata/ml_results/rnn/"

#"/Users/workplacelivetv/Library/CloudStorage/GoogleDrive-robo01.rpa@gmail.com/My Drive/ml_data/yh_his/D1/"
#filepath = "/Users/workplacelivetv/Library/CloudStorage/GoogleDrive-robo01.rpa@gmail.com/My Drive/ml_data/yh_his/D1/QBTS.csv"
symbol = '#AMZN'
df = pd.read_csv (folderPath_His + symbol + ".csv")
#df = pd.read_csv (filepath)
# Daten laden
#df = yf.download("TSLA", start="2018-01-01", end=None)

lastBars = 0
n_tail = 200
n_pred_days = 60
n_time_steps = 60 # Neuronal Netzwerk
sequence_length = 60
n_epochs = 200 
n_batch_size = 16
df_his = df.tail(lastBars+1)
df_his["date"] = pd.to_datetime(df_his["date"]) 


df = df[['date','open', 'high', 'low', 'close','volume']]
df['date'] = pd.to_datetime(df['date'])
df = df.set_index('date')
df_full = df.copy()

#data = df.copy()
if n_tail > 0: df = df.tail(n_tail)
if lastBars > 0: df = df[: len(df)-lastBars]
df = df[['close']].dropna()
# Out:
# /tmp/ipykernel_476130/649607752.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_his["date"] = pd.to_datetime(df_his["date"])

# %%
# 2. Daten skalieren
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(df)
filePath_model =  folderPath_models +symbol+ ".keras"
model_name = filePath_model

# 3. Sequenzen vorbereiten
n_steps = 60
forecast_horizon = 7

X, y = [], []
for i in range(n_steps, len(scaled_data) - forecast_horizon):
    X.append(scaled_data[i - n_steps:i])
    y.append(scaled_data[i:i + forecast_horizon].flatten())

X, y = np.array(X), np.array(y)
X = X.reshape((X.shape[0], X.shape[1], 1))
import os 

if os.path.exists(model_name) == False:

  # 4. RNN-Modell erstellen
  model = Sequential([
    SimpleRNN(50, activation='tanh', input_shape=(n_steps, 1)),
    Dense(forecast_horizon)
   ])
  model.compile(optimizer='adam', loss='mean_squared_error')
  # 5. Modell trainieren
  model.fit(X, y, epochs=100, batch_size=32, verbose=1)
  save_model(model, model_name)
  


# --- Modell speichern ---

model_pred = load_model(model_name)

# 6. Vorhersage für die nächsten 7 Wochentage
last_sequence = scaled_data[-n_steps:]
last_sequence = last_sequence.reshape((1, n_steps, 1))
predicted_scaled = model.predict(last_sequence)
predicted_prices = scaler.inverse_transform(predicted_scaled)[0]


# 7. Nur Montag bis Freitag generieren
last_date = df.index[-1]
predicted_dates = []
day_offset = 1
while len(predicted_dates) < forecast_horizon:
    next_date = last_date + datetime.timedelta(days=day_offset)
    if next_date.weekday() < 5:  # 0=Montag, ..., 4=Freitag
        predicted_dates.append(next_date)
    day_offset += 1
# Out:
# Epoch 1/100
# /home/aiubuntu01/anaconda3/envs/tf-gpu/lib/python3.12/site-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 2025-11-20 21:38:07.808297: I external/local_xla/xla/service/service.cc:163] XLA service 0x7f6b68004630 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2025-11-20 21:38:07.808331: I external/local_xla/xla/service/service.cc:171]   StreamExecutor device (0): NVIDIA GeForce RTX 3080 Ti, Compute Capability 8.6
# 2025-11-20 21:38:07.849951: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-11-20 21:38:07.969838: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:473] Loaded cuDNN version 91501
# 3/5 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.6552
# I0000 00:00:1763671089.193252  476373 device_compiler.h:196] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 291ms/step - loss: 0.5407
# Epoch 2/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.2717
# Epoch 3/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1597
# Epoch 4/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0714
# Epoch 5/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0319
# Epoch 6/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0195
# Epoch 7/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0176
# Epoch 8/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0138
# Epoch 9/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0094
# Epoch 10/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0075
# Epoch 11/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0071
# Epoch 12/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0060
# Epoch 13/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0055
# Epoch 14/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0054
# Epoch 15/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0051
# Epoch 16/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0044
# Epoch 17/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0042
# Epoch 18/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0042
# Epoch 19/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0041
# Epoch 20/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0040
# Epoch 21/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0040
# Epoch 22/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0038
# Epoch 23/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0037
# Epoch 24/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0038
# Epoch 25/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0042
# Epoch 26/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0037
# Epoch 27/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0036
# Epoch 28/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0037
# Epoch 29/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0042
# Epoch 30/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0040
# Epoch 31/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0037
# Epoch 32/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0035
# Epoch 33/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0035
# Epoch 34/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0034
# Epoch 35/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0035
# Epoch 36/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0035
# Epoch 37/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0034
# Epoch 38/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0033
# Epoch 39/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0033
# Epoch 40/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0036
# Epoch 41/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0032
# Epoch 42/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0032
# Epoch 43/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0032
# Epoch 44/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0032
# Epoch 45/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0033
# Epoch 46/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0031
# Epoch 47/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0032
# Epoch 48/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0031
# Epoch 49/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0031
# Epoch 50/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0032
# Epoch 51/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0031
# Epoch 52/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0035
# Epoch 53/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0030
# Epoch 54/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0034
# Epoch 55/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0031
# Epoch 56/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0031
# Epoch 57/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0031
# Epoch 58/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0032
# Epoch 59/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0031
# Epoch 60/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0033
# Epoch 61/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0033
# Epoch 62/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0040
# Epoch 63/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0036
# Epoch 64/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0031
# Epoch 65/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0037
# Epoch 66/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0029
# Epoch 67/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0034
# Epoch 68/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0037
# Epoch 69/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0030
# Epoch 70/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0031
# Epoch 71/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0031
# Epoch 72/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0030
# Epoch 73/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0032
# Epoch 74/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0032
# Epoch 75/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0031
# Epoch 76/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0032
# Epoch 77/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0029
# Epoch 78/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0030
# Epoch 79/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0029
# Epoch 80/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0032
# Epoch 81/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0029
# Epoch 82/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0029
# Epoch 83/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0029
# Epoch 84/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0030
# Epoch 85/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0029
# Epoch 86/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0031
# Epoch 87/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0029
# Epoch 88/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0032
# Epoch 89/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0036
# Epoch 90/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0030
# Epoch 91/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0030
# Epoch 92/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0034
# Epoch 93/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0032
# Epoch 94/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0031
# Epoch 95/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0030
# Epoch 96/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0031
# Epoch 97/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0029
# Epoch 98/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0029
# Epoch 99/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0029
# Epoch 100/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0030
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step

# %%
# 8. Plot: Historische Daten + Vorhersage
df = df.tail(10)
df_his = df_his.set_index('date')
df_his = df_his.tail(lastBars)
plt.figure(figsize=(12, 6))
plt.plot(df.index, df['close'], label='Historische Daten')
plt.plot(df_his.index, df_his['close'], label='IS-HIS')
plt.plot(predicted_dates, predicted_prices, marker='o', linestyle='--', color='red', label='Vorhersage (nur Wochentage)')
plt.title(symbol + ' Historie und 7-Tage-Vorhersage (RNN)')
plt.xlabel('Datum')
plt.ylabel('Preis in USD')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
predicted_dates
# Out:
# [Timestamp('2025-11-20 00:00:00'),
#  Timestamp('2025-11-21 00:00:00'),
#  Timestamp('2025-11-24 00:00:00'),
#  Timestamp('2025-11-25 00:00:00'),
#  Timestamp('2025-11-26 00:00:00'),
#  Timestamp('2025-11-27 00:00:00'),
#  Timestamp('2025-11-28 00:00:00')]

# %%
# 8. DataFrame erstellen
last_close = df['close'].iloc[-1]
result_df = pd.DataFrame({
    'Symbol': [symbol]*7,
    'Type': ['TS']*7,
    'Date': predicted_dates,
    'Close': predicted_prices,
    'Source': [last_close]*forecast_horizon,
    'Change': 0
})
result_df['Change'] = df['Close'].pct_change() * 100
print (result_df.head())
# 9. Ausgabe
result_df.to_csv(folderpath_results+symbol +".csv")
